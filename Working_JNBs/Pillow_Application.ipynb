# %%
session = {}
'id' in session.keys()
# Out:
# False

# %%
import urllib
from PIL import Image
import io

unaltered_image = urllib.request.urlopen( 'http://0.0.0.0:5000/static/Unedited_Image/03c6af53ebe840dd.jpg' ).read()

image = Image.open(io.BytesIO(unaltered_image))
width, height = image.size
maxwidth = 1024
maxheight = 732

if width > maxwidth or height > maxheight:
    new_width = int(width * min(maxwidth/width, maxheight/height))
    new_height = int(height * min(maxwidth/width, maxheight/height))
    image = image.resize((new_width, new_height), Image.ANTIALIAS)
else:
    pass

# %%
image.size
# Out:
# (948, 732)

# %%
image = image.resize((new_width, new_height), Image.ANTIALIAS)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-25-a132267e1a63> in <module>
# ----> 1 image = image.resize((new_width, new_height), Image.ANTIALIAS)
#
# ~/.conda/envs/PassageWay/lib/python3.7/site-packages/PIL/Image.py in resize(self, size, resample, box, reducing_gap)
#    1903                 )
#    1904
# -> 1905         return self._new(self.im.resize(size, resample, box))
#    1906
#    1907     def reduce(self, factor, box=None):
#
# TypeError: integer argument expected, got float

# %%
image.size
# Out:
# (3116, 2405)

# %%
width, height = image.size

# %%
maxwidth = 1024
maxheight = 732

# %%
new_width = width * min(maxwidth/width, maxheight/height)
new_height = height * min(maxwidth/width, maxheight/height)

# %%
new_height
# Out:
# 732.0

# %%
from PIL import Image
from PIL import ImageFont
from PIL import ImageDraw

img = Image.open("/Users/Mango/Desktop/PassageWay/PassageWay_App/static/Styled_Image/Image_Unaltered.jpg")

draw = ImageDraw.ImageDraw(img)
# font = ImageFont.truetype(<font-file>, <font-size>)
font = ImageFont.truetype('/Users/Mango/Desktop/PassageWay/PassageWay_App/fonts/accid__.ttf', 54)
spacing = 10
# draw.text((x, y),"Sample Text",(r,g,b))
text = "bloooooawewgeewefffffbl \noooooawewgeewefffffbloooo \noawewgeewefffffblooooo \nnawewgeewefffffblo \nooooawewgeewefffff bloooooawewgeeweffff"
draw.multiline_text((50, 50), text, fill ="#FF0000", font = font, spacing = spacing, align ="left")

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1024x683 at 0x7F7F604CBEB8>

# %%
W, H = img.size

# %%
w, h = draw.textsize(text)

# %%
(W-w)/2,(H-h)/2
# Out:
# (395.0, 306.0)

# %%
w, h = draw.textsize(text)
draw.text(((W-w)/2,(H-h)/2), msg, fill="black")

# %%
img.show()

# %%
todays_date = datetime.datetime.now()
month = mydate.strftime("%B")
year = datetime.datetime.now().year

# %%
web_address = "https://en.wikiquote.org/wiki/Wikiquote:Quote_of_the_day/" + month + "_" + str(year)

# %%
web_address
# Out:
# 'https://en.wikiquote.org/wiki/Wikiquote:Quote_of_the_day/June_2020'

# %%
datetime.datetime.now().year
# Out:
# 2020
